# %%
#IMPORT NECESSARY LIBRARIES

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#READ THE DATA
data = pd.read_csv('AQI.csv')
data.head(5)
# Out:
#          Date  PM2.5   PM10     NO    NO2    NOx    NH3    CO   SO2     O3  \
# 0  07-07-2016  35.33  84.31  16.95  44.35  34.22  12.06  0.84  5.07  25.24
# 1  08-07-2016  40.64  92.73  28.48  52.89  47.01  11.91  1.07  6.57  16.24
# 2  09-07-2016  33.25  77.65  23.32  45.37  39.49  12.77  1.00  8.79  18.38
# 3  10-07-2016  26.64  69.68  11.03  36.51  26.00  12.82  0.88  9.97  27.98
# 4  11-07-2016  23.92  70.52  13.89  39.01  29.35  12.46  0.89  9.72  24.73
#
#    AQI    AQI_Bucket
# 0   81  Satisfactory
# 1  112      Moderate
# 2   81  Satisfactory
# 3   81  Satisfactory
# 4   79  Satisfactory

# %%
# DATAFRAME
df = pd.DataFrame(data)
df
# Out:
#             Date  PM2.5   PM10     NO    NO2    NOx    NH3    CO    SO2  \
# 0     07-07-2016  35.33  84.31  16.95  44.35  34.22  12.06  0.84   5.07
# 1     08-07-2016  40.64  92.73  28.48  52.89  47.01  11.91  1.07   6.57
# 2     09-07-2016  33.25  77.65  23.32  45.37  39.49  12.77  1.00   8.79
# 3     10-07-2016  26.64  69.68  11.03  36.51  26.00  12.82  0.88   9.97
# 4     11-07-2016  23.92  70.52  13.89  39.01  29.35  12.46  0.89   9.72
# ...          ...    ...    ...    ...    ...    ...    ...   ...    ...
# 1116  24-06-2020  34.36  90.90   1.22  23.38  13.12  14.45  0.56  10.92
# 1117  25-06-2020  13.45  58.54   2.30  21.60  13.09  12.27  0.41   8.19
# 1118  26-06-2020   7.63  32.27   5.91  23.27  17.19  11.15  0.46   6.87
# 1119  27-06-2020  15.02  50.94   7.68  25.06  19.54  12.47  0.47   8.55
# 1120  28-06-2020  24.38  74.09   3.42  26.06  16.53  11.99  0.52  12.72
#
#          O3  AQI    AQI_Bucket
# 0     25.24   81  Satisfactory
# 1     16.24  112      Moderate
# ...

# %%
# DROP THE 'Date' column
df = data.drop(columns=['Date','AQI_Bucket'])
df
# Out:
#       PM2.5   PM10     NO    NO2    NOx    NH3    CO    SO2     O3  AQI
# 0     35.33  84.31  16.95  44.35  34.22  12.06  0.84   5.07  25.24   81
# 1     40.64  92.73  28.48  52.89  47.01  11.91  1.07   6.57  16.24  112
# 2     33.25  77.65  23.32  45.37  39.49  12.77  1.00   8.79  18.38   81
# 3     26.64  69.68  11.03  36.51  26.00  12.82  0.88   9.97  27.98   81
# 4     23.92  70.52  13.89  39.01  29.35  12.46  0.89   9.72  24.73   79
# ...     ...    ...    ...    ...    ...    ...   ...    ...    ...  ...
# 1116  34.36  90.90   1.22  23.38  13.12  14.45  0.56  10.92  35.12   86
# 1117  13.45  58.54   2.30  21.60  13.09  12.27  0.41   8.19  29.38   77
# 1118   7.63  32.27   5.91  23.27  17.19  11.15  0.46   6.87  19.90   47
# 1119  15.02  50.94   7.68  25.06  19.54  12.47  0.47   8.55  23.30   41
# 1120  24.38  74.09   3.42  26.06  16.53  11.99  0.52  12.72  30.14   70
#
# [1121 rows x 10 columns]

# %%
#LAST DATA
df.tail()
# Out:
#       PM2.5   PM10    NO    NO2    NOx    NH3    CO    SO2     O3  AQI
# 1116  34.36  90.90  1.22  23.38  13.12  14.45  0.56  10.92  35.12   86
# 1117  13.45  58.54  2.30  21.60  13.09  12.27  0.41   8.19  29.38   77
# 1118   7.63  32.27  5.91  23.27  17.19  11.15  0.46   6.87  19.90   47
# 1119  15.02  50.94  7.68  25.06  19.54  12.47  0.47   8.55  23.30   41
# 1120  24.38  74.09  3.42  26.06  16.53  11.99  0.52  12.72  30.14   70

# %%
#SHAPE OF DATA
print('The shape of our features is:', df.shape)
# Out:
# The shape of our features is: (1121, 10)

# %%
#INFORMATION OF DATA
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1121 entries, 0 to 1120
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PM2.5   1121 non-null   float64
#  1   PM10    1121 non-null   float64
#  2   NO      1121 non-null   float64
#  3   NO2     1121 non-null   float64
#  4   NOx     1121 non-null   float64
#  5   NH3     1121 non-null   float64
#  6   CO      1121 non-null   float64
#  7   SO2     1121 non-null   float64
#  8   O3      1121 non-null   float64
#  9   AQI     1121 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 87.7 KB

# %%
#INPUT PARAMETERS - 7 INPUTS
from sklearn.model_selection import train_test_split
X=(df.iloc[:,0:9])
X
# Out:
#       PM2.5   PM10     NO    NO2    NOx    NH3    CO    SO2     O3
# 0     35.33  84.31  16.95  44.35  34.22  12.06  0.84   5.07  25.24
# 1     40.64  92.73  28.48  52.89  47.01  11.91  1.07   6.57  16.24
# 2     33.25  77.65  23.32  45.37  39.49  12.77  1.00   8.79  18.38
# 3     26.64  69.68  11.03  36.51  26.00  12.82  0.88   9.97  27.98
# 4     23.92  70.52  13.89  39.01  29.35  12.46  0.89   9.72  24.73
# ...     ...    ...    ...    ...    ...    ...   ...    ...    ...
# 1116  34.36  90.90   1.22  23.38  13.12  14.45  0.56  10.92  35.12
# 1117  13.45  58.54   2.30  21.60  13.09  12.27  0.41   8.19  29.38
# 1118   7.63  32.27   5.91  23.27  17.19  11.15  0.46   6.87  19.90
# 1119  15.02  50.94   7.68  25.06  19.54  12.47  0.47   8.55  23.30
# 1120  24.38  74.09   3.42  26.06  16.53  11.99  0.52  12.72  30.14
#
# [1121 rows x 9 columns]

# %%
#OUTPUT PARAMETERS - BOD
from sklearn.model_selection import train_test_split
y=(df.iloc[:,-1:])
y
# Out:
#       AQI
# 0      81
# 1     112
# 2      81
# 3      81
# 4      79
# ...   ...
# 1116   86
# 1117   77
# 1118   47
# 1119   41
# 1120   70
#
# [1121 rows x 1 columns]

# %%
df.describe()
# Out:
#              PM2.5         PM10           NO          NO2          NOx  \
# count  1121.000000  1121.000000  1121.000000  1121.000000  1121.000000
# mean     47.213078   106.810232    13.092810    37.274112    29.770205
# std      28.275088    48.799159    10.831941    16.249989    15.152231
# min       2.000000     8.160000     0.440000     0.170000     0.170000
# 25%      27.290000    76.610000     5.170000    26.210000    19.330000
# 50%      40.460000   100.660000    10.840000    35.570000    27.360000
# 75%      63.140000   124.880000    17.410000    44.950000    37.030000
# max     203.050000   326.400000    90.840000   130.260000   117.990000
#
#                NH3           CO          SO2           O3          AQI
# count  1121.000000  1121.000000  1121.000000  1121.000000  1121.000000
# mean     11.228314     0.852186    12.841311    36.920187   116.631579
# std       5.271124     0.358039     8.412207    27.004063    54.895671
# ...

# %%
#CHARACTERISTICS OF DATA
df.describe()
# Out:
#              PM2.5         PM10           NO          NO2          NOx  \
# count  1121.000000  1121.000000  1121.000000  1121.000000  1121.000000
# mean     47.213078   106.810232    13.092810    37.274112    29.770205
# std      28.275088    48.799159    10.831941    16.249989    15.152231
# min       2.000000     8.160000     0.440000     0.170000     0.170000
# 25%      27.290000    76.610000     5.170000    26.210000    19.330000
# 50%      40.460000   100.660000    10.840000    35.570000    27.360000
# 75%      63.140000   124.880000    17.410000    44.950000    37.030000
# max     203.050000   326.400000    90.840000   130.260000   117.990000
#
#                NH3           CO          SO2           O3          AQI
# count  1121.000000  1121.000000  1121.000000  1121.000000  1121.000000
# mean     11.228314     0.852186    12.841311    36.920187   116.631579
# std       5.271124     0.358039     8.412207    27.004063    54.895671
# ...

# %%
df.corr()
# Out:
#           PM2.5      PM10        NO       NO2       NOx       NH3        CO  \
# PM2.5  1.000000  0.855203  0.324421  0.575659  0.512378  0.377030  0.584529
# PM10   0.855203  1.000000  0.387320  0.629381  0.593816  0.362820  0.493005
# NO     0.324421  0.387320  1.000000  0.593832  0.887942  0.176114  0.531099
# NO2    0.575659  0.629381  0.593832  1.000000  0.883620  0.318476  0.537860
# NOx    0.512378  0.593816  0.887942  0.883620  1.000000  0.266678  0.574310
# NH3    0.377030  0.362820  0.176114  0.318476  0.266678  1.000000  0.278489
# CO     0.584529  0.493005  0.531099  0.537860  0.574310  0.278489  1.000000
# SO2    0.125476  0.140136  0.315910  0.345316  0.340811  0.068555  0.261586
# O3     0.576710  0.359037 -0.128415  0.134924 -0.004197  0.193644  0.268894
# AQI    0.891182  0.855570  0.339277  0.538194  0.508602  0.334284  0.526333
#
#             SO2        O3       AQI
# PM2.5  0.125476  0.576710  0.891182
# PM10   0.140136  0.359037  0.855570
# ...

# %%
#HEATMAP
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
#CHECK IF ANY DATA IS NULL
df.isnull().sum()
# Out:
# PM2.5    0
# PM10     0
# NO       0
# NO2      0
# NOx      0
# NH3      0
# CO       0
# SO2      0
# O3       0
# AQI      0
# dtype: int64

# %%
#IMPORT FOR PLOTTING
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# DATA COUNT OF AQI
sns.countplot('PM2.5', data=X)
plt.show()
# Out:
# C:\Users\Neela\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot( df['AQI'] )
# Out:
# C:\Users\Neela\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AQI'>

# %%
sns.distplot(df['PM2.5'])
# Out:
# C:\Users\Neela\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PM2.5', ylabel='Density'>

# %%
sns.boxplot(df['NH3'] )
# Out:
# C:\Users\Neela\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NH3'>

# %%
df['O3'].value_counts()
# Out:
# 20.53    3
# 19.68    3
# 15.00    3
# 28.63    3
# 13.08    3
#         ..
# 11.81    1
# 20.39    1
# 57.75    1
# 51.39    1
# 30.14    1
# Name: O3, Length: 1035, dtype: int64

# %%
sns.countplot('CO', data=X)
plt.show()
# Out:
# C:\Users\Neela\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(df)

# %%
import seaborn
import seaborn as sns
seaborn.scatterplot(df['PM2.5'],df['AQI'])
# Out:
# C:\Users\Neela\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PM2.5', ylabel='AQI'>

# %%
seaborn.scatterplot(df['CO'],df['AQI'])
# Out:
# C:\Users\Neela\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CO', ylabel='AQI'>

# %%
#VIOLIN PLOT

sns.catplot(data=df,height=5,aspect=3.0,kind='violin')
# Add labels to the axes
plt.xlabel("Parameters")
plt.ylabel("Values")
# Show the plot
plt.show()
# Out:
# C:\Users\Neela\anaconda3\lib\site-packages\seaborn\categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# C:\Users\Neela\anaconda3\lib\site-packages\seaborn\categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]

# %%
#TRAINING AND TESTING DATA SPLIT
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,shuffle=True)
train_test_split(y, random_state=46)
y_test
# Out:
#       AQI
# 895   284
# 840   113
# 262    93
# 873    97
# 1007  119
# ...   ...
# 835    98
# 236   136
# 533   129
# 1107   92
# 771    97
#
# [281 rows x 1 columns]

# %%
print('Training Features Shape:', y_train.shape)
print('Testing Features Shape:', y_test.shape)
# Out:
# Training Features Shape: (840, 1)
# Testing Features Shape: (281, 1)

# %%
print('Training Features Shape:', X_train.shape)
print('Testing Features Shape:', X_test.shape)
# Out:
# Training Features Shape: (840, 9)
# Testing Features Shape: (281, 9)

# %%
#MLP Regression for AQI Prediction 
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler



regressor=MLPRegressor(hidden_layer_sizes=(100),
  activation='relu', solver='adam', alpha=0.001,
  batch_size='auto', learning_rate='constant',
  learning_rate_init=0.001, power_t=0.5, max_iter=200,
  shuffle=True, random_state=None, tol=0.0001,
  verbose=False, warm_start=False, momentum=0.9,
  nesterovs_momentum=True, early_stopping=False,
  validation_fraction=0.1, beta_1=0.9, beta_2=0.999,
  epsilon=1e-08, n_iter_no_change=10, max_fun=15000)

model=regressor.fit(X_train,y_train.values.ravel())
y_pred=model.predict(X_test)
y_pred
# Out:
# C:\Users\Neela\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# array([ 82.03161748, 135.67201779,  85.53989413, 100.86974426,
#        124.0210723 , 140.23320077, 103.74502476, 134.29527423,
#        127.12547114,  80.02650218, 277.44529228,  90.86190402,
#        161.4475696 ,  97.02901247, 147.24949884, 137.85773899,
#         92.14549684,  68.07326387, 158.00313199,  86.80192167,
#         92.32793565,  65.69153634, 131.37088319, 116.3740977 ,
#        134.22548633, 116.48267766,  76.36173853, 100.05754079,
#         78.46847509, 171.60252771, 107.05704256,  97.77835723,
#         67.1462914 , 184.46303929, 120.4080938 ,  67.46285164,
#         51.25272706, 127.45375831,  68.098514  , 250.78237833,
#        292.5780071 ,  88.77240117,  97.01746584, 120.28281196,
# ...

# %%
# MLP ERROR

from sklearn import metrics 
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import numpy as np
print('Mean Absolute  error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared error:',metrics.mean_squared_error(y_test,y_pred))
print('Root Mean square error:',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print('coefficient of determination:', metrics.r2_score(y_test,y_pred))
# Out:
# Mean Absolute  error: 15.772174638309968
# Mean Squared error: 600.6499625189329
# Root Mean square error: 24.5081611411165
# coefficient of determination: 0.7802468946503529

# %%
import matplotlib.pyplot as plt
# plotting the data
plt.scatter(y_test, y_pred)
plt.title("AQI-MLP")
plt.xlabel('Observed AQI')
plt.ylabel('Predicted AQI')
plt.show()

# %%
# AQI USING LINEAR REGRESSION

from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
Lregressor=LinearRegression() 
model1=Lregressor.fit(X_train,y_train.values.ravel())
y_pred1=model1.predict(X_test)
y_pred1
# Out:
# array([ 92.29017311, 134.82171349,  83.26666587,  96.19169405,
#        123.63928544, 147.3530203 , 100.22400388, 132.64617026,
#        127.1542806 ,  80.42583555, 260.29566496,  81.01389063,
#        142.77515444,  99.21800167, 143.83464021, 145.22265246,
#         89.95229319,  63.44671841, 162.12842178,  77.52012979,
#         92.75483024,  57.94494501, 136.78972314, 115.5483997 ,
#        136.95509184, 112.82295419,  85.35046148, 100.52362231,
#         79.484395  , 166.68816153, 112.18700981, 105.10425344,
#         67.8461341 , 188.51650346, 127.12599874,  68.8016774 ,
#         61.13593011, 128.58822688,  74.01287607, 240.08550915,
#        282.11239913,  94.0304659 ,  95.6034893 , 125.57644865,
#        136.18965658, 133.66737376, 200.31694283,  89.87895306,
#         97.81891145, 111.2812054 , 156.16882261, 144.63830149,
#         94.58233459, 121.32362552, 143.76907931, 115.72222229,
#        107.96075249, 144.39910393, 126.87449016,  74.36838944,
# ...

# %%
#ERROR FOR LINEAR REGRESSION
from sklearn import metrics 
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import numpy as np
print('Mean Absolute  error:', metrics.mean_absolute_error(y_test, y_pred1))
print('Mean Squared error:',metrics.mean_squared_error(y_test,y_pred1))
print('Root Mean square error:',np.sqrt(metrics.mean_squared_error(y_test,y_pred1)))
print('coefficient of determination:', metrics.r2_score(y_test,y_pred1))
# Out:
# Mean Absolute  error: 16.34606812809141
# Mean Squared error: 610.0237849479644
# Root Mean square error: 24.698659577960186
# coefficient of determination: 0.7768173987437234

# %%
# Retrieve the coefficients and intercept
coef = model1.coef_
intercept = model1.intercept_

print("Coefficients:", coef)
print("Intercept:", intercept)
# Out:
# Coefficients: [ 0.97185034  0.4500168  -0.69733107 -0.95545472  1.35259801 -0.11541597
#   3.40609889  0.32000269  0.22683985]
# Intercept: 13.473651002343814

# %%
import matplotlib.pyplot as plt
# plotting the data
plt.scatter(y_test, y_pred1)
plt.title("AQI-Linear Regression")
plt.xlabel('Observed AQI')
plt.ylabel('Predicted AQI')
plt.show()

# %%
# Decision Tree Regression FOR AQI PREDICTION
from sklearn.tree import DecisionTreeRegressor

Dregressor=DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
                      max_features=None, max_leaf_nodes=None,
                      min_impurity_decrease=0.0, min_impurity_split=None,
                      min_samples_leaf=1, min_samples_split=2,
                      min_weight_fraction_leaf=0.0, random_state=0, splitter='best')

model2=Dregressor.fit(X_train,y_train.values.ravel())
y_pred2=model2.predict(X_test)
y_pred2
# Out:
# array([110., 126.,  83., 155., 112., 113.,  96., 119., 142.,  89., 274.,
#         79., 111.,  82., 151., 152., 101.,  61., 179.,  92.,  72.,  56.,
#        107., 121., 110., 122.,  95., 122.,  90., 148., 114.,  98.,  76.,
#        182., 118.,  79., 122., 110.,  90., 271., 315.,  91., 101., 149.,
#        115., 116., 233., 102.,  90.,  87., 151., 142., 102., 104., 135.,
#        129., 125., 107.,  98.,  91., 226.,  63.,  91.,  60.,  50., 141.,
#        226.,  77., 108.,  87., 100.,  95., 292.,  69., 135.,  87., 105.,
#         69., 163., 134.,  50.,  67., 142., 214.,  79.,  88., 163., 129.,
#         97., 103., 131., 158.,  72., 276.,  77.,  85., 205., 147., 277.,
#        114., 126., 111.,  93.,  96., 100.,  52., 229., 117., 113., 133.,
#         96., 110., 122., 119., 315., 110.,  89., 127.,  51.,  81.,  76.,
#         90.,  87.,  74., 157., 111., 151.,  52.,  68.,  99., 114., 150.,
#         90., 121., 140.,  63., 116., 114., 150., 121.,  84., 127.,  90.,
# ...

# %%
#ERROR FOR BayesianRidge Regression
from sklearn import metrics 
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import numpy as np
print('Mean Absolute  error:', metrics.mean_absolute_error(y_test, y_pred2))
print('Mean Squared error:',metrics.mean_squared_error(y_test,y_pred2))
print('Root Mean square error:',np.sqrt(metrics.mean_squared_error(y_test,y_pred2)))
print('coefficient of determination:', metrics.r2_score(y_test,y_pred2))
# Out:
# Mean Absolute  error: 19.8576512455516
# Mean Squared error: 857.6298932384342
# Root Mean square error: 29.285318732061533
# coefficient of determination: 0.6862285123777201

# %%
import matplotlib.pyplot as plt
# plotting the data
plt.scatter(y_test, y_pred2)
plt.title("AQI-DECISION TREE Regression")
plt.xlabel('Observed AQI')
plt.ylabel('Predicted AQI')
plt.show()

# %%
observed = np.array(y_test)
observed
# Out:
# array([[284],
#        [113],
#        [ 93],
#        [ 97],
#        [119],
#        [144],
#        [ 97],
#        [121],
#        [107],
#        [105],
#        [315],
#        [138],
#        [131],
#        [ 87],
#        [140],
#        [122],
#        [ 82],
#        [110],
#        [105],
#        [117],
#        [ 76],
#        [ 53],
#        [136],
#        [106],
#        [138],
#        [107],
#        [ 75],
#        [111],
#        [ 77],
#        [117],
#        [103],
#        [108],
#        [ 77],
#        [144],
#        [122],
#        [ 70],
#        [108],
#        [ 87],
#        [ 78],
#        [296],
#        [279],
#        [ 86],
#        [101],
#        [109],
#        [131],
#        [117],
#        [164],
#        [106],
#        [ 98],
#        [101],
#        [163],
#        [143],
#        [ 99],
#        [118],
#        [140],
#        [112],
#        [125],
#        [142],
#        [147],
#        [ 81],
#        [272],
#        [ 53],
# ...

# %%
#TABLE FOR AQI VALUES BY ALL THREE TECHNIQUES
# import module
from tabulate import tabulate

# assign data
mydata = ['observed','y_pred','y_pred1','y_pred2']

# Combine into a list of lists for tabulate
predictions = list(zip(observed,y_pred, y_pred1, y_pred2))

# Headers for the table
headers = ["observed AQI","AQI-MLP", "AQI-Linear Regression", "AQI-Decision Tree Regression"]

# Print the table using tabulate with "pretty" table format for better alignment
print(tabulate(predictions, headers=headers, tablefmt="pretty"))
# Out:
# +--------------+--------------------+-----------------------+------------------------------+
# | observed AQI |      AQI-MLP       | AQI-Linear Regression | AQI-Decision Tree Regression |
# +--------------+--------------------+-----------------------+------------------------------+
# |    [284]     | 82.03161748473548  |   92.29017310555851   |            110.0             |
# |    [113]     | 135.6720177918498  |  134.82171349278516   |            126.0             |
# |     [93]     | 85.53989413312732  |   83.26666587345203   |             83.0             |
# |     [97]     | 100.86974426177242 |   96.19169405083348   |            155.0             |
# |    [119]     | 124.02107229563838 |  123.63928543568056   |            112.0             |
# |    [144]     | 140.23320077178414 |   147.3530203006609   |            113.0             |
# |     [97]     | 103.74502476304595 |  100.22400388417888   |             96.0             |
# ...

# %%
#ERRORS 
errorxg1=np.sqrt(metrics.mean_squared_error(y_test,y_pred))
errorxg2=metrics.r2_score(y_test,y_pred)
errorLR1=np.sqrt(metrics.mean_squared_error(y_test,y_pred1))
errorLR2=metrics.r2_score(y_test,y_pred1)
errorBR1=np.sqrt(metrics.mean_squared_error(y_test,y_pred2))
errorBR2=metrics.r2_score(y_test,y_pred2)

# %%
# ERRORS IN A TABLE
data = [[errorxg1, errorLR1,errorBR1],[errorxg2, errorLR2,errorBR2]   ]

# Additional column data
error_metrics = ["Root mean squared error", "Coefficient of determination"]

# Add the additional column to the left of each row in data
for i in range(len(data)):
    data[i] = [error_metrics[i]] + data[i]

# Headers for the table including the new column
headers = ["ERROR", "MLP", "Linear Regression", "Decision Tree Regre"]

# Calculate maximum width for each column
max_widths = [max(len(str(row[i])) for row in data) for i in range(len(headers))]

# Print the table
print("+" + "+".join("-" * (width + 2) for width in max_widths) + "+")
print("|" + "|".join(f" {headers[i]:^{max_widths[i]}} " for i in range(len(headers))) + "|")
print("+" + "+".join("-" * (width + 2) for width in max_widths) + "+")
for row in data:
    print("|" + "|".join(f" {str(cell):^{max_widths[i]}} " for i, cell in enumerate(row)) + "|")

print("+" + "+".join("-" * (width + 2) for width in max_widths) + "+")
# Out:
# +------------------------------+--------------------+--------------------+--------------------+
# |            ERROR             |        MLP         | Linear Regression  | Decision Tree Regre |
# +------------------------------+--------------------+--------------------+--------------------+
# |   Root mean squared error    |  24.5081611411165  | 24.698659577960186 | 29.285318732061533 |
# | Coefficient of determination | 0.7802468946503529 | 0.7768173987437234 | 0.6862285123777201 |
# +------------------------------+--------------------+--------------------+--------------------+

# %%
def classify_y_pred(y_pred):
    classifications = []
    for value in y_pred:
        if value >= 23 and value <= 50:
            classifications.append("Good")
        elif value >= 51 and value <= 100:
            classifications.append("Satisfactory")
        elif value >= 101 and value <= 200:
            classifications.append("Moderate")
        elif value >= 203 and value <= 299:
            classifications.append("Poor")
        elif value >= 302 and value <= 387:
            classifications.append("Very poor")
        else:
            classifications.append("Unknown")  # Handle cases outside the defined ranges if needed
    return classifications

# Example list of y_pred values (replace with your actual list)
y_pred_list = y_pred

# Classify each y_pred value
classified_values = classify_y_pred(y_pred_list)

# Print the classified values
for i, value in enumerate(y_pred_list):
    print(f"Value: {value} -> Classification: {classified_values[i]}")
# Out:
# Value: 82.03161748473548 -> Classification: Satisfactory
# Value: 135.6720177918498 -> Classification: Moderate
# Value: 85.53989413312732 -> Classification: Satisfactory
# Value: 100.86974426177242 -> Classification: Unknown
# Value: 124.02107229563838 -> Classification: Moderate
# Value: 140.23320077178414 -> Classification: Moderate
# Value: 103.74502476304595 -> Classification: Moderate
# Value: 134.2952742306558 -> Classification: Moderate
# Value: 127.12547114085758 -> Classification: Moderate
# Value: 80.0265021780262 -> Classification: Satisfactory
# Value: 277.4452922792759 -> Classification: Poor
# Value: 90.86190402480158 -> Classification: Satisfactory
# Value: 161.44756959766832 -> Classification: Moderate
# Value: 97.02901246634364 -> Classification: Satisfactory
# Value: 147.2494988412626 -> Classification: Moderate
# Value: 137.85773899376218 -> Classification: Moderate
# Value: 92.14549684280914 -> Classification: Satisfactory
# ...

# %%
def classify_y_pred(y_pred):
    classifications = []
    for value in y_pred:
        if value >= 23 and value <= 50:
            classifications.append("Good")
        elif value >= 51 and value <= 100:
            classifications.append("Satisfactory")
        elif value >= 101 and value <= 200:
            classifications.append("Moderate")
        elif value >= 203 and value <= 299:
            classifications.append("Poor")
        elif value >= 302 and value <= 387:
            classifications.append("Very poor")
        else:
            classifications.append("Unknown")  # Handle cases outside the defined ranges if needed
    return classifications

# Example list of y_pred values (replace with your actual list)
y_pred_list1 = y_pred1

# Classify each y_pred value
classified_values1 = classify_y_pred(y_pred_list1)

# Print the classified values
for i, value in enumerate(y_pred_list1):
    print(f"Value: {value} -> Classification: {classified_values[i]}")
# Out:
# Value: 92.29017310555851 -> Classification: Satisfactory
# Value: 134.82171349278516 -> Classification: Moderate
# Value: 83.26666587345203 -> Classification: Satisfactory
# Value: 96.19169405083348 -> Classification: Unknown
# Value: 123.63928543568056 -> Classification: Moderate
# Value: 147.3530203006609 -> Classification: Moderate
# Value: 100.22400388417888 -> Classification: Moderate
# Value: 132.64617025766356 -> Classification: Moderate
# Value: 127.15428060225224 -> Classification: Moderate
# Value: 80.42583555481374 -> Classification: Satisfactory
# Value: 260.29566495906886 -> Classification: Poor
# Value: 81.01389063270817 -> Classification: Satisfactory
# Value: 142.77515443817617 -> Classification: Moderate
# Value: 99.21800167338682 -> Classification: Satisfactory
# Value: 143.83464021307338 -> Classification: Moderate
# Value: 145.2226524647858 -> Classification: Moderate
# Value: 89.95229318533455 -> Classification: Satisfactory
# ...

# %%
def classify_y_pred(y_pred):
    classifications = []
    for value in y_pred:
        if value >= 23 and value <= 50:
            classifications.append("Good")
        elif value >= 51 and value <= 100:
            classifications.append("Satisfactory")
        elif value >= 101 and value <= 200:
            classifications.append("Moderate")
        elif value >= 203 and value <= 299:
            classifications.append("Poor")
        elif value >= 302 and value <= 387:
            classifications.append("Very poor")
        else:
            classifications.append("Unknown")  # Handle cases outside the defined ranges if needed
    return classifications

# Example list of y_pred values (replace with your actual list)
y_pred_list2 = y_pred2

# Classify each y_pred value
classified_values2 = classify_y_pred(y_pred_list2)

# Print the classified values
for i, value in enumerate(y_pred_list2):
    print(f"Value: {value} -> Classification: {classified_values[i]}")
# Out:
# Value: 110.0 -> Classification: Satisfactory
# Value: 126.0 -> Classification: Moderate
# Value: 83.0 -> Classification: Satisfactory
# Value: 155.0 -> Classification: Unknown
# Value: 112.0 -> Classification: Moderate
# Value: 113.0 -> Classification: Moderate
# Value: 96.0 -> Classification: Moderate
# Value: 119.0 -> Classification: Moderate
# Value: 142.0 -> Classification: Moderate
# Value: 89.0 -> Classification: Satisfactory
# Value: 274.0 -> Classification: Poor
# Value: 79.0 -> Classification: Satisfactory
# Value: 111.0 -> Classification: Moderate
# Value: 82.0 -> Classification: Satisfactory
# Value: 151.0 -> Classification: Moderate
# Value: 152.0 -> Classification: Moderate
# Value: 101.0 -> Classification: Satisfactory
# Value: 61.0 -> Classification: Satisfactory
# Value: 179.0 -> Classification: Moderate
# Value: 92.0 -> Classification: Satisfactory
# Value: 72.0 -> Classification: Satisfactory
# Value: 56.0 -> Classification: Satisfactory
# ...

# %%
from tabulate import tabulate

# Combine into a list of lists for tabulate
predictions = []
for i in range(len(y_pred_list)):
    predictions.append([y_pred_list[i], classified_values[i], y_pred_list1[i], classified_values1[i], y_pred_list2[i], classified_values2[i]])

# Headers for the table
headers = ["AQI-MLP", "Classification", "AQI-Linear Regression", "Classification", "AQI-Decision Tree Regression", "Classification"]

# Print the table using tabulate with "pretty" table format for better alignment
print(tabulate(predictions, headers=headers, tablefmt="pretty"))
# Out:
# +--------------------+----------------+-----------------------+----------------+------------------------------+----------------+
# |      AQI-MLP       | Classification | AQI-Linear Regression | Classification | AQI-Decision Tree Regression | Classification |
# +--------------------+----------------+-----------------------+----------------+------------------------------+----------------+
# | 82.03161748473548  |  Satisfactory  |   92.29017310555851   |  Satisfactory  |            110.0             |    Moderate    |
# | 135.6720177918498  |    Moderate    |  134.82171349278516   |    Moderate    |            126.0             |    Moderate    |
# | 85.53989413312732  |  Satisfactory  |   83.26666587345203   |  Satisfactory  |             83.0             |  Satisfactory  |
# | 100.86974426177242 |    Unknown     |   96.19169405083348   |  Satisfactory  |            155.0             |    Moderate    |
# ...
